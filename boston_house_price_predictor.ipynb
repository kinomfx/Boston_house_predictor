# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d = pd.read_csv('boston-housing/train.csv')
d
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.2 KB

# %%
d.corr()['medv']
# Out:
# ID        -0.221694
# crim      -0.407454
# zn         0.344842
# indus     -0.473932
# chas       0.204390
# nox       -0.413054
# rm         0.689598
# age       -0.358888
# dis        0.249422
# rad       -0.352251
# tax       -0.448078
# ptratio   -0.481376
# black      0.336660
# lstat     -0.738600
# medv       1.000000
# Name: medv, dtype: float64

# %%
y = d['medv']

# %%
d.drop(columns=['medv','ID'] ,inplace = True)
x=d

# %%
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4    0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       18.7  394.63   2.94
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      33.4
# 3      36.2
# 4      22.9
#        ...
# 328    17.5
# 329    22.4
# 330    20.6
# 331    23.9
# 332    11.9
# Name: medv, Length: 333, dtype: float64

# %%
x.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x , y)
# Out:
# LinearRegression()

# %%
df = pd.read_csv('boston-housing/test.csv')
index = df['ID']
df.drop(columns=['ID'],inplace = True)
df2 = pd.DataFrame(model.predict(df.to_numpy()),columns=['Medv'])
df2.insert(0,'ID',index)
df2
# Out:
# C:\Users\Monik\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
#       ID       Medv
# 0      3  30.599594
# 1      6  25.100459
# 2      8  18.158993
# 3      9   9.303476
# 4     10  17.689729
# ..   ...        ...
# 168  496  16.763294
# 169  497  13.415179
# 170  499  21.361446
# 171  501  20.341302
# 172  505  26.675488
#
# [173 rows x 2 columns]

# %%
import pickle
file = open('model2.pkl','wb')
pickle.dump(model,file)
file.close()
